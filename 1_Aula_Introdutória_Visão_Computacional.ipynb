# %% [markdown]
# <a href="https://colab.research.google.com/github/profandersonvanin01/machine_learning/blob/main/1_Aula_Introdut%C3%B3ria_Vis%C3%A3o_Computacional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # O que é Visão Computacional
#
# A visão computacional tem sido usada diariamente nos negócios para realizar vários tipos de tarefas, incluindo diagnóstico médico, classificação de produtos, veículos autônomos, segurança etc. A tecnologia e todas as tarefas acima, exigem mais do que apenas reconhecimento de imagem, mas também análise semântica de grandes conjuntos de dados (GONZALEZ, 2002).
#
# A visão computacional é considerada uma subárea de processamento de imagens. Alguns autores definem como uma ciência, o que faz com que as máquinas tenham possibilidade de ver, como o reconhecimento de imagem (CONCI et al., 2008).
#
# A visão computacional é um dos ramos da inteligência artificial que estuda o processamento de imagens do mundo real por um computador. Em outras palavras, essa área investiga maneiras de dar às máquinas a capacidade de interpretar visualmente informações, ou seja, enxergar.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# fonte: https://www.serpro.gov.br/menu/noticias/noticias-2020/o-que-eh-visao-computacional/imagem1artigo.png/@@images/eeb269b6-1014-4539-a03d-946d931d535f.png

# %% [markdown]
# ## Algumas aplicações da Visão Computacional
#
# - Uso Militar
# - Veículos Autônomos
# - Marketing
# - Segurança
# - Serviços Públicos
# - Processos Produtivos
# - Saúde
# ...

# %% [markdown]
# # Conceitos Básicos
#
# A visão computacional é um "pacotão" que engloba tudo, desde a coleta da imagem, o seu pré-processamento, o tratamento da imagem.
#
# ##  - Imagens
#
# A imagem digital é composta de vários “quadradinhos” coloridos, que são chamados de pixels. O pixel é: a menor unidade que compõe uma imagem digital.
#
# O pixel é como um pedaço muito pequeno que compõe o “mosaico” que falamos anteriormente, contendo a informação de luz que citamos sobre aquele pequeno pedaço da imagem.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Se considerarmos que cada pixel possui 3 canais de cores (R,G e B) teremos um total de **32 x 32 x 3 = 3072 pixels** para serem avaliados.

# %% [markdown]
# Quando trabalhamos com a análise de imagens em Visão Computacional, é muito comum converter uma imagem colorida com 3 canais de cores, para uma imagem com um único canal em tons de cinza. Assim para a imagem acima precisaremos analisar 32 x 32 x 1 = 1024 pixels, o que reduz bastante o custo computacional do sistema.

# %% [markdown]
# ## - Processamento de Imagens
# O processamento consiste em organizar todas as imagens, colocá-las na mesma escala, aplicar um filtro, etc. Nesse processo, enventualmente veremos que algumas das imagens não estão bem realçadas, e teremos que aumentar o seu realce, ou teremos que tirar alguma cor da imagem; transformá-las para a escala de cinza, etc. Todas essas aplicações que faremos nas imagens antes de rodar os algoritmos de machine learning fazem parte da etapa de processamento de imagens.

# %% [markdown]
# # Classificação de imagens
#
# É claro que a visão computacional vai muito além disso, muito além de se trabalhar com classificação somente. E o que é a classificação? É quando pegamos uma imagem e temos que classificar o que está nela. Então, aprendemos a fazer isso para poder dizer: nesta imagem existe um gato; esta imagem é de um navio; de um avião. Isto é a classificação de imagens.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Detecção de objetos
# Mas, além da classificação de imagens, podemos fazer a detecção de objetos dentro delas. E como se diferencia a detecção de objetos da classificação? Enquanto na classificação apenas dizemos: “Essa figura é de um gato”, na detecção de objetos dizemos que não só a figura é de um gato, mas dizemos onde está o gato; podemos desenhar um retângulo, uma caixa em volta do gato que aparece na figura. Assim estamos passando duas informações: não somente que existe um gato na figura, mas, também, dizemos onde ele está na figura.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Nesse caso, a rede neural tem que aprender duas coisas: não só a identificar as imagens específicas, como, também, a localizá-las, a ver onde elas estão posicionadas dentro da figura. Esse é um trabalho dobrado que a rede neural vai ter que aprender, e isso é a detecção de objetos. Esse é um outro campo que também está dentro da visão computacional.

# %% [markdown]
# # Segmentação de instância
# Além da detecção de objetos, ainda podemos fazer a segmentação de instância. O que é isso? A segmentação de instância vai um pouco além da detecção de objetos, e tira um contorno completo do objeto: não somente fazemos um retângulo ou quadrado em volta da figura que encontramos e identificamos, mas fazemos um recorte detalhado de todo o objeto, como se fôssemos recortá-lo com uma tesoura, em todo o contorno onde acreditamos que aquele objeto está, ou ainda em mais de um objeto na mesma figura.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # PARTE PRÁTICA
#
# Antes de mais nada, é conveniente criar uma pasta em seu Drive do Google com o nome: Visão_Computacional_CPS e dentro desta pasta inserir algumas imagens que serão utilizadas neste primeiro exemplo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Estas imagens também podem ser obtidas em: https://github.com/profandersonvanin01/laboratorio_ia/tree/main/Imagens

# %% [markdown]
# # OPENCV
# ##  - Carregamento de uma imagem

# %% [markdown]
# https://opencv.org/
#
# OpenCV (Open Source Computer Vision) é uma biblioteca de programação, de código aberto e inicialmente desenvolvida pela Intel com o objetivo de tornar a visão computacional mais acessível a desenvolvedores e hobistas. Atualmente possui mais de 500 funções, pode ser utilizada em diversas linguagens de programação (C++, Python, Ruby, Java…) e é usada para diversos tipos de análise em imagens e vídeos, como  detecção, tracking e reconhecimento facial, edição de fotos e vídeos, detecção e análise de textos, etc.

# %%
import cv2

# %% [markdown]
# Conectando ao Google Drive para acessar os arquivos de imagens

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Carregando uma imagem em uma variável

# %%
imagem = cv2.imread('/content/drive/MyDrive/Visao_Computacional_CPS/imagens/people1.jpg')

# %% [markdown]
# Visualizando o tamanho da imagem

# %%
imagem.shape

# %% [markdown]
# Visualizando a imagem importada

# %%
cv2.imshow(imagem)

# %% [markdown]
# O comando cv2.imshow() é desabilitado no Colab por questões de segurança da aplicação. Precisamos fazer, então uma importação específica que só utilizada dentro do ambiente Colab do Google.

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(imagem)

# %% [markdown]
# Repare que temos uma imagem bem grande (1280 x 1920 x 3). Portanto, vamos aplicar uma etapa de processamento para reduzir um pouco o tamanho desta imagem.

# %%
imagem_reduzida = cv2.resize(imagem, (800,600))

# %% [markdown]
# Verifique o novo tamanho da imagem

# %%
imagem_reduzida.shape

# %%
cv2_imshow(imagem_reduzida)

# %% [markdown]
# Vamos salvar uma cópia desta imagem para usarmos na representação final

# %%
cv2.imwrite('/content/drive/MyDrive/Visao_Computacional_CPS/salvas/imagem_colorida.png',imagem_reduzida)

# %% [markdown]
# Continuando na etapa de processamento, vamos agora converter esta imagem para uma outra em escala de cinza.

# %%
imagem_cinza = cv2.cvtColor(imagem_reduzida, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(imagem_cinza)

# %% [markdown]
# Vamos verificar o "shape" desta imagem:

# %%
imagem_cinza.shape

# %% [markdown]
# Vamos salvar essa imagem já Pré-processada para podermos utilizá-la na próxima aula.

# %%
cv2.imwrite('/content/drive/MyDrive/Visao_Computacional_CPS/salvas/imagem_cinza.png',imagem_cinza)

# %% [markdown]
# # Parabéns
#
# Chegamos ao final da 1ª aula sobre Visão Computacional. Nesta aula você aprendeu sobre o que é Visão Computacional e alguns conceitos básicos sobre Pixels, Imagens e Processamento de Imagens.
